# %% [markdown]
# # Get Benchmark for Celeba Dataset

# %%
import torch
import numpy as np

import sys,os
sys.path.append("..")
 
from src.plotters import PCA_plot_q_p_samples, plot_images
from src.map_benchmark import Celeba64Benchmark
from src.methods import DOT_metrics

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Hyper-parameters

# %%
NUM_SAMPLES_PLOT = 1000


DEG, WIDTH =  100, 16 # or DEG, WIDTH = 10, 1
SEED = 295 # Hard coded
 
GPU_DEVICE = 1
torch.cuda.set_device(GPU_DEVICE)

# %% [markdown]
# ## 1. Benchmark

# %%
benchmark = Celeba64Benchmark(width=WIDTH, deg=DEG, seed=SEED)
torch.cuda.empty_cache()
# Out:
# Benchmark pair loaded

# %% [markdown]
# ## 2. Motion samples

# %%
torch.manual_seed(153); np.random.seed(153)

# %%
fig,axes = PCA_plot_q_p_samples(benchmark, NUM_SAMPLES_PLOT, 8,4, path=None, flag_p=True)

# %% [markdown]
# ## 3. Images

# %%
torch.manual_seed(8);np.random.seed(8)

# %%
fig,axes = plot_images(benchmark,10,path=None,shape=(3,64,64))

# %% [markdown]
# ## 4. Discrete Optimal Transport

# %%
w1, l2, cos = DOT_metrics(benchmark,  batch_size = 1000 )

# %%
w1, l2, cos
# Out:
# (50.915977478027344, 1.4705616235733032, 0.26471930742263794)

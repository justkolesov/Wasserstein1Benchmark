# %% [markdown]
# # Get N-dimensional benchmark  : From P to Q

# %%
import torch

import sys,os
sys.path.append("..")

from src.plotters import  PCA_plot_q_p_samples, plot_benchmark_2d_info
from src.map_benchmark import MixToOneBenchmark
from src.methods import DOT_metrics, calculate_unbiased_wasserstein

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Hyper-parameters

# %%
DIM = 4
WIDTH =  64
SEED = 987
GPU_DEVICE = 0

# %%
NUM_SAMPLES_PLOT = 40
NUM_SAMPLES_PLOT_PCA = 2000
BATCH_SIZE =  2000

assert torch.cuda.is_available()
torch.cuda.set_device(GPU_DEVICE)

# %% [markdown]
# ## 1. Benchmark

# %%
benchmark = MixToOneBenchmark(dim=DIM,width=WIDTH, seed=SEED)
# Out:
# benchmark pair loaded

# %% [markdown]
# ## 2. Plottings : boarders, trays and motion

# %%
if DIM == 2:
    fig,axes = plot_benchmark_2d_info(benchmark, NUM_SAMPLES_PLOT, fix=3, fiy=3, cmap="pink" )

# %% [markdown]
# ## 3. PCA : Motion Samples

# %%
fig,axes = PCA_plot_q_p_samples(benchmark, NUM_SAMPLES_PLOT_PCA, 12, 6 ,path = None , flag_p = False)

# %% [markdown]
# ## 4. Discrete Optimal Transport Test

# %%
discrete_distance, l2_dot , cos_dot  = DOT_metrics(benchmark,  4000,True)

# %%
discrete_distance ,l2_dot ,cos_dot
# Out:
# (1.6206841468811035, 1.8688481318029915e-10, 1.0)
